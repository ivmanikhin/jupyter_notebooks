# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import os
import numpy as np
import pathlib
import random

# %%
for dirpath, dirnames, filenames in os.walk("pizza_steak"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'")
# Out:
# There are 2 directories and 0 images in 'pizza_steak'
# There are 2 directories and 0 images in 'pizza_steak\test'
# There are 0 directories and 250 images in 'pizza_steak\test\pizza'
# There are 0 directories and 250 images in 'pizza_steak\test\steak'
# There are 2 directories and 0 images in 'pizza_steak\train'
# There are 0 directories and 750 images in 'pizza_steak\train\pizza'
# There are 0 directories and 750 images in 'pizza_steak\train\steak'

# %%
num_steak_images_train = len(os.listdir("pizza_steak/train/steak"))

num_steak_images_train
# Out:
# 750

# %%
# get class names - names of folders in directory "pizza_steak/train"
data_dir = pathlib.Path("pizza_steak/train")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_names)
# Out:
# ['pizza' 'steak']

# %%
# visualise images
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    print(f"Image shape: {img.shape}")
    return img

# %%
img = view_random_image("pizza_steak/train/", "steak")
# tf.constant(img)
# Out:
# Image shape: (384, 512, 3)

# %%
tf.random.set_seed(42)

# normalize data
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# setup path to directories
train_dir = "pizza_steak/train"
test_dir = "pizza_steak/test"

# import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(directory=train_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               seed=42)
valid_data = valid_datagen.flow_from_directory(directory=test_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               seed=42)

# build a CNN model
model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=10,
                           kernel_size=3,
                           activation="elu",
                           input_shape=(224, 224, 3)),
    tf.keras.layers.Conv2D(10, 3, activation="elu"),
    tf.keras.layers.MaxPool2D(pool_size=2,
                              padding="valid"),
    tf.keras.layers.Conv2D(10, 3, activation="elu"),
    tf.keras.layers.Conv2D(10, 3, activation="elu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# compile model
model_1.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

history = model_1.fit(train_data,
                      epochs=5,
                      steps_per_epoch=len(train_data),
                      validation_data=valid_data,
                      validation_steps=len(valid_data))
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Epoch 1/5
# 47/47 [==============================] - 31s 643ms/step - loss: 0.5719 - accuracy: 0.6993 - val_loss: 0.4295 - val_accuracy: 0.8000
# Epoch 2/5
# 47/47 [==============================] - 29s 626ms/step - loss: 0.4660 - accuracy: 0.7893 - val_loss: 0.4804 - val_accuracy: 0.7440
# Epoch 3/5
# 47/47 [==============================] - 29s 627ms/step - loss: 0.4450 - accuracy: 0.7947 - val_loss: 0.4045 - val_accuracy: 0.8260
# Epoch 4/5
# 47/47 [==============================] - 29s 622ms/step - loss: 0.3972 - accuracy: 0.8247 - val_loss: 0.3824 - val_accuracy: 0.8260
# Epoch 5/5
# 47/47 [==============================] - 29s 618ms/step - loss: 0.3661 - accuracy: 0.8460 - val_loss: 0.4112 - val_accuracy: 0.8120
